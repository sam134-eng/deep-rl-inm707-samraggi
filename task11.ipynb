# %%
pip install gym gym-anytrading stable-baselines3 torch
# Out:
# ...
#
# ...

# %%
# !pip install stable-baselines3[extra]

# %%
# !pip install "shimmy>=2.0"

# %%
import gym
import numpy as np
from stable_baselines3 import SAC
from stable_baselines3.common.evaluation import evaluate_policy

# Create the Pendulum environment
env = gym.make("Pendulum-v1")

# Initialize SAC model
model = SAC("MlpPolicy", env, verbose=1)

# Train the model (keep timesteps limited to ~20,000 to finish within 1 hour)
model.learn(total_timesteps=20000)

# Evaluate the trained agent
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10)
print(f"Mean Reward over 10 episodes: {mean_reward:.2f} ± {std_reward:.2f}")

# Visualize performance (renders one episode)
obs = env.reset()
for _ in range(200):
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, done, info = env.step(action)
    env.render()
env.close()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# C:\Users\hp\anaconda3\anaconda\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# C:\Users\hp\anaconda3\anaconda\Lib\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.42e+03 |
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 28        |
# |    time_elapsed    | 28        |
# ...
